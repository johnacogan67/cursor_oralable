# %% [markdown]
# # First peek: raw nRF log and HEX strings
#
# Load the first 100 lines of a log in `data/raw/` and show the raw HEX strings so we can confirm the parser can see them.

# %%
from pathlib import Path
import re

raw_dir = Path("../data/raw")
if not raw_dir.exists():
    raw_dir = Path("data/raw")  # run from repo root

log_files = [f for f in raw_dir.iterdir() if f.suffix.lower() in (".txt", ".csv") and f.name != "README.md"]
log_files.sort(key=lambda p: p.name)
log_file = log_files[0] if log_files else None
print(f"Using log: {log_file}" if log_file else "No .txt/.csv in data/raw/")
print(f"Files in data/raw: {[f.name for f in raw_dir.iterdir() if f.is_file()]}")
# Out:
# Using log: ../data/raw/Oralable_20260228_025215.txt
# Files in data/raw: ['Oralable_20260302_081321.txt', 'Oralable_20260228_025215.txt']

# %%
if log_file:
    lines = log_file.read_text(encoding="utf-8", errors="replace").splitlines()
    first_100 = lines[:100]
    print(f"Total lines in file: {len(lines)}")
    print(f"First 100 lines:\n")
    for i, line in enumerate(first_100, 1):
        print(f"{i:3d} | {line[:120]}{'...' if len(line) > 120 else ''}")
else:
    print("No log file to load.")
# Out:
# Total lines in file: 8483
# First 100 lines:
#
#   1 | 02:52:21.437 - Characteristic (3A0FF003-98C4-46B2-94AF-1AEE0FD4C48E) notified: <1ED30000 9E070000>
#   2 | 02:52:21.495 - Characteristic (3A0FF002-98C4-46B2-94AF-1AEE0FD4C48E) notified: <7DA70100 841E9C16 5C30881E B0164C30 781E...
#   3 | 02:52:21.705 - Characteristic (3A0FF001-98C4-46B2-94AF-1AEE0FD4C48E) notified: <6F110200 FC170000 FD110000 00120000 FB17...
#   4 | 02:52:21.976 - Characteristic (3A0FF002-98C4-46B2-94AF-1AEE0FD4C48E) notified: <7EA70100 881EB016 5830781E C8164C30 A41E...
#   5 | 02:52:22.096 - Characteristic (3A0FF001-98C4-46B2-94AF-1AEE0FD4C48E) notified: <70110200 FF170000 00120000 02120000 FE17...
#   6 | 02:52:22.425 - Characteristic (3A0FF003-98C4-46B2-94AF-1AEE0FD4C48E) notified: <1FD30000 D0070000>
#   7 | 02:52:22.485 - Characteristic (3A0FF002-98C4-46B2-94AF-1AEE0FD4C48E) notified: <7FA70100 A41EB416 5C30941E C4163C30 8C1E...
# ...

# %% [markdown]
# ## Raw HEX strings the parser would see
#
# Extract and show the HEX payload from lines that look like BLE notifications (3A0FF001 PPG, `value: (0x)`, or `notified: <...>`).

# %%
if not log_file:
    raise SystemExit("No log file.")

lines = log_file.read_text(encoding="utf-8", errors="replace").splitlines()[:100]

def get_hex_snippet(line: str):
    """Return (source, hex_preview) for lines that contain BLE payload HEX."""
    line_lower = line.lower()
    if "3a0ff001" not in line_lower and "3a0ff002" not in line_lower and "3a0ff003" not in line_lower:
        return None
    # nRF Android: value: (0x) A7-1F-00-00-...
    if "value: (0x)" in line:
        start = line.find("value: (0x)") + len("value: (0x)")
        rest = line[start:].strip()
        return ("value: (0x)", rest[:200] + ("..." if len(rest) > 200 else ""))
    # iOS/dash: notified: <ad0c0000 00000000 ...>
    if "notified:" in line and "<" in line and ">" in line:
        start = line.find("<") + 1
        end = line.find(">", start)
        if start > 0 and end > start:
            hex_part = line[start:end].strip()
            return ("notified: <...>", hex_part[:200] + ("..." if len(hex_part) > 200 else ""))
    # CSV/bracket: " to F600 0000 ..."
    if " to " in line and "Updated Value" in line:
        start = line.find(" to ") + 4
        rest = line[start:].strip()
        return (" to ", rest[:200] + ("..." if len(rest) > 200 else ""))
    return None

print("Raw HEX snippets (first 100 lines):\n")
count = 0
for i, line in enumerate(lines, 1):
    out = get_hex_snippet(line)
    if out:
        count += 1
        source, hex_preview = out
        print(f"Line {i} [{source}]:")
        print(f"  {hex_preview}")
        print()
print(f"Total lines with HEX payload in first 100: {count}")
# Out:
# Raw HEX snippets (first 100 lines):
#
# Line 1 [notified: <...>]:
#   1ED30000 9E070000
#
# Line 2 [notified: <...>]:
#   7DA70100 841E9C16 5C30881E B0164C30 781E9816 3030981E B8168430 7C1EB816 4830681E 94166C30 841EB816 64307C1E D0165430 641ECC16 5C30741E B8165830 8C1EB816 7030881E AC168830 9C1E9416 7430701E B0167830 78...
#
# Line 3 [notified: <...>]:
#   6F110200 FC170000 FD110000 00120000 FB170000 00120000 00120000 FC170000 00120000 01120000 FB170000 01120000 00120000 FA170000 00120000 FF110000 FD170000 00120000 00120000 FC170000 FF110000 00120000 00...
#
# Line 4 [notified: <...>]:
#   7EA70100 881EB016 5830781E C8164C30 A41EC416 5030601E D0166C30 481ED016 78306C1E C0164C30 741EC016 54308C1E A8164830 7C1EA016 4830941E 88166C30 C41E9C16 F4305C1E BC163C30 741EDC16 7C30701E C0165430 7C...
#
# Line 5 [notified: <...>]:
# ...

# %% [markdown]
# ## Clinical Summary Generator
#
# `generate_clinical_report()` produces publication-ready plots proving the device detects:
# - **Plot A (Apnea Signal):** PPG IR-DC with Clench Detection overlay and Occlusion Depth (% drop)
# - **Plot B (Bruxing Signal):** Accelerometer Z-Axis RMS during Grinding vs Quiet Sleep
#
# Uses `GOLD_STANDARD_VALIDATION.csv` as ground truth for phase labels.

# %%
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path.cwd() if (Path.cwd() / "data").exists() else Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.analysis.features import compute_filters


def _parse_gold_standard(gt_path: Path) -> dict:
    """Parse GOLD_STANDARD_VALIDATION.csv into phase intervals (start_s, end_s)."""
    df = pd.read_csv(gt_path)
    phases = {"clench": [], "grinding": [], "quiet_sleep": []}  # Rest + Baseline
    for _, row in df.iterrows():
        ev = str(row.get("Event", ""))
        t = float(row.get("ElapsedSeconds", 0))
        if ev.startswith("START:"):
            name = ev.replace("START:", "").strip()
            if "Clench" in name:
                phases["clench"].append((t, None))
            elif "Grinding" in name:
                phases["grinding"].append((t, None))
            elif name in ("Rest", "Baseline"):
                phases["quiet_sleep"].append((t, None))
        elif ev.startswith("END:"):
            name = ev.replace("END:", "").strip()
            if "Clench" in name and phases["clench"]:
                start, _ = phases["clench"][-1]
                phases["clench"][-1] = (start, t)
            elif "Grinding" in name and phases["grinding"]:
                start, _ = phases["grinding"][-1]
                phases["grinding"][-1] = (start, t)
            elif name in ("Rest", "Baseline") and phases["quiet_sleep"]:
                start, _ = phases["quiet_sleep"][-1]
                phases["quiet_sleep"][-1] = (start, t)
    return phases


def _compute_occlusion_depth(ir_dc: np.ndarray, baseline_s: float, trough_s: float, fs: float = 50.0) -> float:
    """Compute % drop in IR-DC from pre-clench baseline to trough during clench."""
    b_idx = int(baseline_s * fs)
    t_idx = int(trough_s * fs)
    if b_idx < 0 or t_idx >= len(ir_dc):
        return float("nan")
    baseline = np.nanmean(ir_dc[max(0, b_idx - 25) : b_idx + 1])  # ~0.5s before
    trough = np.nanmin(ir_dc[b_idx : min(len(ir_dc), t_idx + 1)])
    if baseline < 1e-9:
        return float("nan")
    return (baseline - trough) / baseline * 100.0


def generate_clinical_report(
    data_path: Path | None = None,
    gold_standard_path: Path | None = None,
    output_path: Path | None = None,
    log_path: Path | None = None,
) -> Path:
    """
    Generate Clinical Summary PDF/PNG for Ed/Pedro: device physiology proof.

    Plot A: PPG IR-DC with Clench Detection flag; labels % drop (Occlusion Depth) during clenches.
    Plot B: Accelerometer Z-Axis RMS power during Grinding vs Quiet Sleep.

    Uses GOLD_STANDARD_VALIDATION.csv as ground truth for phase labels.

    Args:
        data_path: Path to 50Hz CSV (green, red, ir, accel_x/y/z). If None, runs pipeline from log_path.
        gold_standard_path: Path to GOLD_STANDARD_VALIDATION.csv. Default: ROOT/GOLD_STANDARD_VALIDATION.csv
        output_path: Output PDF/PNG path. Default: data/plots/clinical_summary.png
        log_path: Raw BLE log; used if data_path is None to generate 50Hz data.

    Returns:
        Path to saved figure.
    """
    if gold_standard_path is None:
        gold_standard_path = ROOT / "GOLD_STANDARD_VALIDATION.csv"
    if not gold_standard_path.exists():
        raise FileNotFoundError(f"Ground truth not found: {gold_standard_path}")

    if data_path is None:
        from src.validation.self_validate import load_raw_ble_log
        if log_path is None:
            raw_dir = ROOT / "data" / "raw"
            logs = sorted(raw_dir.glob("Oralable_*.txt"), key=lambda p: p.stat().st_mtime, reverse=True)
            log_path = logs[0] if logs else None
        if log_path is None or not Path(log_path).exists():
            raise FileNotFoundError("No 50Hz data and no raw log. Provide data_path or log_path.")
        df = load_raw_ble_log(log_path)
    else:
        df = pd.read_csv(data_path, index_col=0, parse_dates=True)
        df.index = pd.to_datetime(df.index)

    df = compute_filters(df)
    FS = 50.0
    elapsed_s = (df.index - df.index[0]).total_seconds().to_numpy()
    ir_dc = df["ir_dc"].to_numpy()
    accel_z = df["accel_z"].to_numpy() if "accel_z" in df.columns else np.zeros(len(df))

    phases = _parse_gold_standard(gold_standard_path)
    clench_mask = np.zeros(len(df), dtype=bool)
    for start, end in phases["clench"]:
        if end is None:
            continue
        mask = (elapsed_s >= start) & (elapsed_s <= end)
        clench_mask |= mask

    # Occlusion depth per clench interval
    occlusion_depths = []
    for start, end in phases["clench"]:
        if end is None:
            continue
        m = (elapsed_s >= start) & (elapsed_s <= end)
        if not np.any(m):
            continue
        idx = np.where(m)[0]
        seg = ir_dc[idx]
        baseline_val = np.nanmean(ir_dc[max(0, idx[0] - 25) : idx[0] + 1])
        trough_val = np.nanmin(seg)
        if baseline_val > 1e-9:
            pct = (baseline_val - trough_val) / baseline_val * 100.0
            occlusion_depths.append((start + (end - start) / 2, pct))

    # Accel Z RMS for Grinding vs Quiet Sleep
    def rms_in_interval(start_s, end_s):
        m = (elapsed_s >= start_s) & (elapsed_s <= end_s)
        if not np.any(m):
            return float("nan")
        return float(np.sqrt(np.nanmean(accel_z[m] ** 2)))

    rms_grinding = [rms_in_interval(s, e) for s, e in phases["grinding"] if e is not None]
    rms_quiet = [rms_in_interval(s, e) for s, e in phases["quiet_sleep"] if e is not None]
    rms_grinding = [x for x in rms_grinding if np.isfinite(x)]
    rms_quiet = [x for x in rms_quiet if np.isfinite(x)]

    # --- Plot ---
    fig, (ax_a, ax_b) = plt.subplots(2, 1, figsize=(12, 8), sharex=False)
    fig.suptitle("Oralable MAM Clinical Summary — Device Physiology Validation", fontsize=14, fontweight="bold")

    # Plot A: Apnea Signal (IR-DC + Clench + Occlusion Depth)
    ax_a.plot(elapsed_s, ir_dc, color="#2E86AB", linewidth=1.2, label="PPG IR-DC (Hemodynamic Baseline)")
    ax_a.fill_between(elapsed_s, ir_dc.min(), ir_dc.max(), where=clench_mask, alpha=0.35, color="#E94F37", label="Clench (Ground Truth)")
    y_min, y_max = np.nanmin(ir_dc), np.nanmax(ir_dc)
    y_span = max(y_max - y_min, 1.0)
    for t_mid, pct in occlusion_depths:
        seg = ir_dc[(elapsed_s >= t_mid - 2) & (elapsed_s <= t_mid + 2)]
        y_trough = np.nanmin(seg) if len(seg) > 0 else y_min
        ax_a.annotate(f"{pct:.1f}% drop", xy=(t_mid, y_trough),
                      xytext=(t_mid, y_min - y_span * 0.06), ha="center", fontsize=9, color="#E94F37", fontweight="bold")
    ax_a.set_ylabel("IR-DC (raw ADC)")
    ax_a.set_xlabel("Time (s)")
    ax_a.set_title("A. Apnea Signal — Occlusion Depth During Clench")
    ax_a.legend(loc="upper right")
    ax_a.grid(True, alpha=0.3)

    # Plot B: Bruxing Signal (Accel Z RMS: Grinding vs Quiet Sleep)
    # Clean comparison: mean ± std as two bars for Ed/Pedro
    mean_quiet = np.nanmean(rms_quiet) if rms_quiet else 0.0
    std_quiet = np.nanstd(rms_quiet) if len(rms_quiet) > 1 else 0.0
    mean_grind = np.nanmean(rms_grinding) if rms_grinding else 0.0
    std_grind = np.nanstd(rms_grinding) if len(rms_grinding) > 1 else 0.0
    x_pos = [0, 1]
    means = [mean_quiet, mean_grind]
    stds = [std_quiet, std_grind]
    colors = ["#2E86AB", "#E94F37"]
    bars = ax_b.bar(x_pos, means, yerr=stds, color=colors, capsize=6, edgecolor="black", linewidth=0.5)
    ax_b.set_xticks(x_pos)
    ax_b.set_xticklabels(["Quiet Sleep\n(Rest/Baseline)", "Grinding\n(Phasic)"])
    ax_b.set_ylabel("Accel Z RMS (raw)")
    ax_b.set_title("B. Bruxing Signal — Z-Axis RMS: Grinding vs Quiet Sleep")
    ax_b.grid(True, alpha=0.3, axis="y")

    plt.tight_layout()

    if output_path is None:
        output_path = ROOT / "data" / "plots" / "clinical_summary.png"
    output_path = Path(output_path)
    output_path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(output_path, dpi=150, bbox_inches="tight")
    pdf_path = output_path.with_suffix(".pdf")
    fig.savefig(pdf_path, dpi=150, bbox_inches="tight")
    plt.close()
    print(f"Clinical Summary saved: {output_path} and {pdf_path}")
    return output_path

# %%
# Generate Clinical Summary
# Uses self_validate_50hz.csv if present; otherwise runs pipeline from most recent raw log
data_path = ROOT / "data" / "processed" / "self_validate_50hz.csv"
if not data_path.exists():
    data_path = None  # Will load from log via load_raw_ble_log
generate_clinical_report(
    data_path=data_path,
    output_path=ROOT / "data" / "plots" / "clinical_summary.png",
)
# Out:
# Clinical Summary saved: /Users/johnacogan67/work/cursor_oralable/data/plots/clinical_summary.png and /Users/johnacogan67/work/cursor_oralable/data/plots/clinical_summary.pdf
# PosixPath('/Users/johnacogan67/work/cursor_oralable/data/plots/clinical_summary.png')

# %%
# Run Validation Dashboard from 2nd 3-tap sync
# Uses JOHN_COGAN_2ND_SYNC_PROTOCOL.csv (ElapsedSeconds relative to 2nd sync)
from src.validation_dashboard import run_validation_dashboard

ROOT = Path.cwd() if (Path.cwd() / "data").exists() else Path.cwd().parent
val_2nd_sync = ROOT / "data" / "validation_logs" / "JOHN_COGAN_2ND_SYNC_PROTOCOL.csv"
run_validation_dashboard(
    segment_from_sync=2,
    validation_path=val_2nd_sync if val_2nd_sync.exists() else None,
    output_path=ROOT / "data" / "plots" / "validation_dashboard.png",
    root=ROOT,
)
